# %% [markdown]
# <a href="https://colab.research.google.com/github/JorgeHernandez15/FIMEIB/blob/main/Assignment_2_Basics_on_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import Counter
import string
from google.colab import files

def analyze_text(file_content):
    text = file_content.decode('utf-8')

    # Remove punctuation for word analysis
    translator = str.maketrans('', '', string.punctuation)
    text_no_punctuation = text.translate(translator)

    # Split the text into words, sentences, and paragraphs
    words = text_no_punctuation.split()
    sentences = text.split('.')
    paragraphs = text.split('\n\n')

    # Count the number of words, sentences, and paragraphs
    num_words = len(words)
    num_sentences = len(sentences)
    num_paragraphs = len(paragraphs)

    # Calculate the average word length
    total_word_length = sum(len(word) for word in words)
    avg_word_length = total_word_length / num_words if num_words > 0 else 0

    # Identify the most common words and their frequencies
    word_frequencies = Counter(words)
    most_common_words = word_frequencies.most_common(10)  # Get top 10 most common words

    # Output the results
    print(f'Number of words: {num_words}')
    print(f'Number of sentences: {num_sentences}')
    print(f'Number of paragraphs: {num_paragraphs}')
    print(f'Average word length: {avg_word_length:.2f}')
    print('Most common words:')
    for word, frequency in most_common_words:
        print(f'{word}: {frequency}')

# Upload the file in Google Colab
uploaded = files.upload()

# Assuming only one file is uploaded, get the file content
file_name = next(iter(uploaded))
file_content = uploaded[file_name]

# Analyze the text
analyze_text(file_content)
# Out:
#      <input type="file" id="files-8108b1c5-aacf-4183-b5c0-cd7fa39561f1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8108b1c5-aacf-4183-b5c0-cd7fa39561f1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import random

def hangman():
    # Predefined list of words
    words = ["python", "hangman", "turing", "goku", "computer", "algorithm"]

    # Randomly select a word from the list
    word = random.choice(words)
    word_length = len(word)
    guessed_word = ["_"] * word_length
    attempts = 6  # Number of incorrect attempts allowed
    guessed_letters = []

    print("Hangman! (only use lowercase)")
    print(" ".join(guessed_word))

    while attempts > 0 and "_" in guessed_word:
        guess = input("Guess a letter: ").lower()

        if len(guess) != 1 or not guess.isalpha():
            print("Please enter a single letter.")
            continue

        if guess in guessed_letters:
            print("You already guessed that letter.")
            continue

        guessed_letters.append(guess)

        if guess in word:
            print(f"Good guess! {guess} is in the word.")
            for index, letter in enumerate(word):
                if letter == guess:
                    guessed_word[index] = guess
        else:
            attempts -= 1
            print(f"Wrong guess! {guess} is not in the word. You have {attempts} attempts left.")

        print(" ".join(guessed_word))

    if "_" not in guessed_word:
        print("Congratulations! You've guessed the word correctly.")
    else:
        print(f"Sorry, you've run out of attempts. The word was '{word}'.")

# %%
hangman()
# Out:
# Welcome to Hangman! (only use lowercase)
# _ _ _ _ _ _ _
# Guess a letter: o
# Wrong guess! o is not in the word. You have 5 attempts left.
# _ _ _ _ _ _ _
# Guess a letter: a
# Good guess! a is in the word.
# _ a _ _ _ a _
# Guess a letter: h
# Good guess! h is in the word.
# h a _ _ _ a _
# Guess a letter: m
# Good guess! m is in the word.
# h a _ _ m a _
# Guess a letter: g
# Good guess! g is in the word.
# h a _ g m a _
# Guess a letter: n
# Good guess! n is in the word.
# h a n g m a n
# Congratulations! You've guessed the word correctly.

# %%
import random

def number_guessing_game():
    # Generate a random number between 1 and 100
    target_number = random.randint(1, 100)
    guess = None
    attempts = 0

    print("Number Guessing Game!")
    print("Try to guess the number I choose between 1 and 100.")

    while guess != target_number:
        guess = input("Enter your guess: ")

        # Ensure the input is a number
        if not guess.isdigit():
            print("Please enter a valid number.")
            continue

        guess = int(guess)
        attempts += 1

        if guess < target_number:
            print("Too low! Try again.")
        elif guess > target_number:
            print("Too high! Try again.")
        else:
            print(f"Congratulations! You've guessed the number {target_number} in {attempts} attempts.")

# %%
number_guessing_game()
# Out:
# Number Guessing Game!
# Try to guess the number I choose between 1 and 100.
# Enter your guess: 5
# Too low! Try again.
# Enter your guess: 60
# Too low! Try again.
# Enter your guess: 80
# Too high! Try again.
# Enter your guess: 70
# Too low! Try again.
# Enter your guess: 75
# Too high! Try again.
# Enter your guess: 73
# Too high! Try again.
# Enter your guess: 72
# Congratulations! You've guessed the number 72 in 7 attempts.
