# %% [markdown]
# <a href="https://colab.research.google.com/github/JorgeHernandez15/FIMEIB/blob/main/Text_Analysis_Tool.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import Counter
import string
from google.colab import files

def analyze_text(file_content):
    text = file_content.decode('utf-8')

    # Remove punctuation for word analysis
    translator = str.maketrans('', '', string.punctuation)
    text_no_punctuation = text.translate(translator)

    # Split the text into words, sentences, and paragraphs
    words = text_no_punctuation.split()
    sentences = text.split('.')
    paragraphs = text.split('\n\n')

    # Count the number of words, sentences, and paragraphs
    num_words = len(words)
    num_sentences = len(sentences)
    num_paragraphs = len(paragraphs)

    # Calculate the average word length
    total_word_length = sum(len(word) for word in words)
    avg_word_length = total_word_length / num_words if num_words > 0 else 0

    # Identify the most common words and their frequencies
    word_frequencies = Counter(words)
    most_common_words = word_frequencies.most_common(10)  # Get top 10 most common words

    # Output the results
    print(f'Number of words: {num_words}')
    print(f'Number of sentences: {num_sentences}')
    print(f'Number of paragraphs: {num_paragraphs}')
    print(f'Average word length: {avg_word_length:.2f}')
    print('Most common words:')
    for word, frequency in most_common_words:
        print(f'{word}: {frequency}')

# Upload the file in Google Colab
uploaded = files.upload()

# Assuming only one file is uploaded, get the file content
file_name = next(iter(uploaded))
file_content = uploaded[file_name]

# Analyze the text
analyze_text(file_content)
# Out:
#      <input type="file" id="files-4a597b54-a1c2-434a-ba3f-68431e2fe716" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4a597b54-a1c2-434a-ba3f-68431e2fe716">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
